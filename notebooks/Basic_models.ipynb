# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from surprise.dataset import Dataset
from surprise.reader import Reader
from surprise import SVDpp
from surprise import accuracy
from collections import defaultdict
from random import shuffle
from sklearn.metrics import root_mean_squared_error as rmse, mean_absolute_error as mae

# %%
df_games = pd.read_csv('../data/df_games_train2.csv')
df_users = pd.read_csv('../data/df_users_train2.csv')
df_groups = pd.read_csv('../data/df_groups.csv')

# %%
df_games.head()
# Out:
#    BGGId            Name                                        Description  \
# 0     88          Torres  torre abstract game resource management tactic...
# 1     91  Paths of Glory  gmt game websitethey call great war year titan...
# 2    150        PitchCar  game entry refer nearly identical game compati...
# 3    171           Chess  chess twoplayer abstract strategy board game r...
# 4    188              Go  appearance player take turn lay stone time sma...
#
#    YearPublished  GameWeight  AvgRating  BayesAvgRating   StdDev  MinPlayers  \
# 0           1999      2.8656    7.10972         6.82406  1.27896           2
# 1           1999      3.8421    8.05888         7.33726  1.64059           2
# 2           1995      1.1263    7.26579         6.99936  1.34552           2
# 3           1475      3.6886    7.15112         6.96557  1.83887           2
# 4          -2200      3.9420    7.63525         7.31794  1.91275           2
#
#    MaxPlayers  ...  Cat:Strategy  Cat:War  Cat:Family Cat:CGS  Cat:Abstract  \
# 0           4  ...             1        0           0       0             1
# 1           2  ...             0        1           0       0             0
# 2           8  ...             0        0           1       0             0
# 3           2  ...             0        0           0       0             1
# 4           2  ...             0        0           0       0             1
#
#    Cat:Party  Cat:Childrens  mask  \
# 0          0              0  True
# 1          0              0  True
# 2          1              0  True
# 3          0              0  True
# 4          0              0  True
#
#                                Description_embedding  \
# 0  [-2.683112726255317, -0.42332172554470826, -1....
# 1  [1.0637854293471487, 0.649491797066982, 0.4205...
# 2  [0.820082462099059, -0.0750128060778531, 1.587...
# 3  [-0.858757313022056, -0.0162148123075708, 0.17...
# 4  [0.09952368867430286, 0.5561095815916068, 0.60...
#
#                                      Image_embedding
# 0  [1.6416904926300049, 0.06321828812360764, 0.39...
# 1  [-1.1839122772216797, -0.6947698593139648, 0.3...
# 2  [1.035536527633667, 1.0266635417938232, -0.521...
# 3  [0.8292618989944458, -0.3407784700393677, 0.03...
# 4  [4.239888668060303, -0.1471511274576187, 0.231...
#
# [5 rows x 51 columns]

# %%
df_users.head()
# Out:
#    BGGId  Rating  Username  isTest
# 0  35865    10.0  zebracat   False
# 1  35865     9.0   Pfahrer   False
# 2  35865     9.0  gregorus   False
# 3  35865     9.0   tryytty   False
# 4  35865     9.0   Tolkana   False

# %%
df_groups.head()
# Out:
#                                       members
# 0                         ['Snawk', 'Opal82']
# 1                 ['David546', 'taragalinas']
# 2  ['Vadorojo', 'Travellingmatti', 'DanKill']
# 3                   ['HeavyAdge', 'Jawaswag']
# 4                      ['Qelha14', 'MarcusK']

# %%
df_users.Username.value_counts().head()
# Out:
# Username
# leffe dubbel      245
# oldgoat3769967    223
# TomVasel          219
# Tolkana           210
# Doel              207
# Name: count, dtype: int64

# %% [markdown]
# # Utils

# %%
def games_min_n(n=9):
    aux = df_games[(df_games.MinPlayers <= n) & (df_games.MaxPlayers >= n)]
    return aux.BGGId

# %% [markdown]
# # Recomendación individual

# %% [markdown]
# ## FunkSVD User only

# %%
reader = Reader(rating_scale=(0, 10))
X_train = Dataset.load_from_df(df_users.loc[df_users.isTest == False, ['Username', 'BGGId', 'Rating']],
                               reader=reader).build_full_trainset()
X_test = list(df_users.loc[df_users.isTest == True, ['Username', 'BGGId', 'Rating']].itertuples(index=False, name=None))

svdpp = SVDpp(n_factors=10, n_epochs=150)
svdpp.fit(X_train)
yhat_svdpp = svdpp.test(X_test)

print(accuracy.mae(yhat_svdpp),
      accuracy.rmse(yhat_svdpp))
# Out:
# MAE:  0.7807
# RMSE: 1.0414
# 0.7807340953557931 1.0414232243677881

# %%
X_recommend = X_train.build_anti_testset()

# %%
predictions = svdpp.test(X_recommend)
predictions
# Out:
# [Prediction(uid='zebracat', iid=163412, r_ui=7.3711534995698615, est=7.550726175626433, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=84876, r_ui=7.3711534995698615, est=7.107102100400906, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=161936, r_ui=7.3711534995698615, est=6.7062351548270485, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=12333, r_ui=7.3711534995698615, est=5.150129443148268, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=54043, r_ui=7.3711534995698615, est=6.899370902940081, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=170216, r_ui=7.3711534995698615, est=6.798186215596172, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=41114, r_ui=7.3711534995698615, est=7.913998083711814, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=193738, r_ui=7.3711534995698615, est=7.374576083011571, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=201808, r_ui=7.3711534995698615, est=6.355270728855381, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=157969, r_ui=7.3711534995698615, est=7.281645723651144, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=124361, r_ui=7.3711534995698615, est=7.532889677814965, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=237182, r_ui=7.3711534995698615, est=6.316304259584154, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=244521, r_ui=7.3711534995698615, est=6.9549688180706575, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=128882, r_ui=7.3711534995698615, est=8.092338386772095, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=124742, r_ui=7.3711534995698615, est=4.123220072871867, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=192291, r_ui=7.3711534995698615, est=6.568560694000831, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=187645, r_ui=7.3711534995698615, est=5.424224559972143, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=224517, r_ui=7.3711534995698615, est=7.420081059164949, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=164928, r_ui=7.3711534995698615, est=6.977037313830267, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=103885, r_ui=7.3711534995698615, est=5.153801667973351, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=147949, r_ui=7.3711534995698615, est=9.406566213875792, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=143741, r_ui=7.3711534995698615, est=6.442967127120714, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=28720, r_ui=7.3711534995698615, est=6.892876799347788, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=198773, r_ui=7.3711534995698615, est=7.717406047037843, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=92828, r_ui=7.3711534995698615, est=7.513250910826628, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=156129, r_ui=7.3711534995698615, est=8.23502472781021, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=160477, r_ui=7.3711534995698615, est=7.210799772653452, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=233078, r_ui=7.3711534995698615, est=6.877113945380383, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=115746, r_ui=7.3711534995698615, est=5.641176722438058, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=175914, r_ui=7.3711534995698615, est=7.388224716979837, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=254640, r_ui=7.3711534995698615, est=7.590889872277978, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=217372, r_ui=7.3711534995698615, est=6.818854282439007, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=209010, r_ui=7.3711534995698615, est=6.566474385250775, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=225694, r_ui=7.3711534995698615, est=8.009077302341826, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=199478, r_ui=7.3711534995698615, est=6.467056376716663, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=198994, r_ui=7.3711534995698615, est=6.080512237163433, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=221107, r_ui=7.3711534995698615, est=5.934639280619489, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=155362, r_ui=7.3711534995698615, est=7.09170629506762, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=503, r_ui=7.3711534995698615, est=7.089680179420878, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=158600, r_ui=7.3711534995698615, est=7.26067911362469, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid=31627, r_ui=7.3711534995698615, est=6.665559131394671, details={'was_impossible': False}),
#  Prediction(uid='zebracat', iid
details={'was_impossible': False}),
#  Prediction(uid='Stavros', iid=191004, r_ui=7.3711534995698615, est=5.959813100787366, details={'was_impossible': False}),
#  Prediction(uid='Stavros', iid=270314, r_ui=7.3711534995698615, est=6.386522113098604, details={'was_impossible': False}),
#  ...]

# %%
def get_top_n(predictions, n=10):
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # for uid, user_ratings in top_n.items():
    #     user_ratings.sort(key=lambda x: x[1], reverse=True)
    #     top_n[uid] = user_ratings

    return top_n

# %%
top_n = get_top_n(predictions)

# %%
top_n2 = {k: {k2: v2 for k2, v2 in v} for k, v in top_n.items()}

# %%
top_n3 = pd.DataFrame(top_n2.values(), index=top_n2.keys()).fillna(-100)

# %%
def get_preds_svdpp(user_list, df_pred):
    df = []
    n = len(user_list)
    filter_list = games_min_n(n)
    df_pred2 = df_pred.loc[:, df_pred.columns.isin(filter_list)]

    for usr in user_list:
        usr_pred = df_pred2.loc[usr].sort_values(ascending=False)
        usr_pred = pd.DataFrame(usr_pred[usr_pred > 0]).T
        if n < usr_pred.size:
            usr_pred = usr_pred.loc[:, usr_pred.columns[:n]].copy()

        df.append(usr_pred)
    df = pd.concat(df, axis=0).reset_index(drop=True).fillna(0)
    return df

# %%
df_groups['members2'] = df_groups['members'].apply(lambda x: eval(x))
df_groups['preds_svdpp'] = df_groups['members2'].apply(lambda x: get_preds_svdpp(x, top_n3))

# %%
df_groups.to_pickle('df_groups_svdpp')

# %% [markdown]
# ## Random

# %%
def random_rank(user_list):
    games = games_min_n(len(user_list)).to_list()
    df = []
    for _ in range(len(user_list)):
        shuffle(games)
        rcm = pd.DataFrame([{games[i]: 10 - i for i in range(10)}])
        df.append(rcm)
    df = pd.concat(df, axis=0).reset_index(drop=True).fillna(0)
    return df


df_groups['preds_random'] = df_groups['members2'].apply(lambda x: random_rank(x))

# %%
df_groups.to_pickle('df_groups_svdpp_random')

# %%
yhat_random = np.random.uniform(1, 10, size=(df_users.shape[0], 1))

print('MAE: ', mae(df_users.Rating, yhat_random))
print('RMSE: ', rmse(df_users.Rating, yhat_random))
# Out:
# MAE:  2.8284895681095956
# RMSE:  3.460299819901082

# %% [markdown]
# ## Most polular

# %%
from sklearn.linear_model import LinearRegression

ranking = df_games.sort_values(by=['Rank:boardgame']).BGGId.to_numpy().reshape(-1, 1)
x = np.linspace(10, 1, len(ranking)).reshape(-1, 1)

popularmap = LinearRegression()

popularmap.fit(ranking, x)

yhat_popular = popularmap.predict(df_users[df_users.isTest].BGGId.to_numpy().reshape(-1, 1))

print('MAE: ', mae(df_users[df_users.isTest].Rating, yhat_popular))
print('RMSE: ', rmse(df_users[df_users.isTest].Rating, yhat_popular))
# Out:
# MAE:  2.188580056325345
# RMSE:  2.4680396869540084

# %%
def rank_popular(user_list):
    ranking = df_games.sort_values(by=['Rank:boardgame']).BGGId.to_list()
    df = []
    for _ in range(len(user_list)):
        rcm = pd.DataFrame([{ranking[i]: 10 - i for i in range(10)}])
        df.append(rcm)
    df = pd.concat(df, axis=0).reset_index(drop=True).fillna(0)
    return df


df_groups['preds_popular'] = df_groups['members2'].apply(lambda x: rank_popular(x))

# %%
df_groups.to_pickle('df_groups_svdpp_random_popular')
